# %%
import pandas as pd
df = pd.read_csv(r"/home/quan/Caro_AI/benchmarks/results/benchmark.csv")
df.head(50)
# Out:
#     state_id                               state_name  depth       algorithm  \
# 0          1                 First move - empty board      2    MinimaxAgent
# 1          1                 First move - empty board      2  AlphaBetaAgent
# 2          1                 First move - empty board      3    MinimaxAgent
# 3          1                 First move - empty board      3  AlphaBetaAgent
# 4          1                 First move - empty board      4    MinimaxAgent
# 5          1                 First move - empty board      4  AlphaBetaAgent
# 6          2                     Mid-game with pieces      2    MinimaxAgent
# 7          2                     Mid-game with pieces      2  AlphaBetaAgent
# 8          2                     Mid-game with pieces      3    MinimaxAgent
# 9          2                     Mid-game with pieces      3  AlphaBetaAgent
# 10         2                     Mid-game with pieces      4    MinimaxAgent
# ...
