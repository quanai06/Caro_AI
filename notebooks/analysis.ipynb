# %%
import pandas as pd
df = pd.read_csv(r"/home/quan/Caro_AI/caro_ai/benchmark/results/benchmark.csv")
df.head(50)
# Out:
#        state_id                                 state_name          category  \
# 0    ai_win_now                      Máy có thể thắng ngay           win_now
# 1    ai_win_now                      Máy có thể thắng ngay           win_now
# 2    ai_win_now                      Máy có thể thắng ngay           win_now
# 3    ai_win_now                      Máy có thể thắng ngay           win_now
# 4    ai_win_now                      Máy có thể thắng ngay           win_now
# 5    ai_win_now                      Máy có thể thắng ngay           win_now
# 6    ai_win_now                      Máy có thể thắng ngay           win_now
# 7    ai_win_now                      Máy có thể thắng ngay           win_now
# 8    ai_win_now                      Máy có thể thắng ngay           win_now
# 9    ai_win_now                      Máy có thể thắng ngay           win_now
# 10   ai_win_now                      Máy có thể thắng ngay           win_now
# ...
